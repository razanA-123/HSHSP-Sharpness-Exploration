# %% [markdown]
# # Range [-1,1]

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(-1,1,0.0013)
np.random.shuffle(y)
y
# Out:
# array([-0.051 , -0.4969, -0.753 , ...,  0.911 , -0.0614, -0.5411])

# %%
inputData=np.array([np.arange(-1,1,.0013),y])
response=inputData[0]+inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0) + exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0008554188111007839

# %%
model=[[operators[5],"pop",operators[5],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2 + x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00010950074421514985

# %%
model=[[operators[6],"pop",operators[6],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0) + sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[7],"pop",operators[7],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# 1/x1 + 1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0011310420900843006

# %%
model=[[operators[8],"pop",operators[8],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0) + cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00014349940760888247

# %%
model=[[operators[9],"pop",operators[9],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0) + sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00014939103223434661

# %%
model=[[operators[10],"pop",operators[10],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0) + tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0005529226333441124

# %%
model=[[operators[11],"pop",operators[11],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0) + acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0) + asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0) + atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018184645377857203

# %%
model=[[operators[14],"pop",operators[14],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0) + tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00019659510385510373

# %%
model=[[operators[15],"pop",operators[15],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0) + log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'sqrt':1,'arccos':1,'arcsin':1,'log':1,'inv':0.001294079,'exp':0.00086646,'tan':0.00055292,'tanh':0.00019659,'arctan':0.0001818,'sqrd':0.00015161,'sin':0.00014939,'cos':0.00014349}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Addition")
plt.title("Addition Operator Combinations [-1,1]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(-1,1,0.0013)
np.random.shuffle(y)
y
# Out:
# array([-0.4007,  0.1518, -0.4982, ...,  0.638 , -0.4371, -0.1485])

# %%
inputData=np.array([np.arange(-1,1,.0013),y])
response=inputData[0]-inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0) - exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0008539373244538102

# %%
model=[[operators[5],"pop",operators[5],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2 - x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 2.125573055284549e-05

# %%
model=[[operators[6],"pop",operators[6],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0) - sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[7],"pop",operators[7],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# -1/x1 + 1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0011838867497110455

# %%
model=[[operators[8],"pop",operators[8],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0) - cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 1.9187197154555222e-05

# %%
model=[[operators[9],"pop",operators[9],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0) - sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00014554444254262977

# %%
model=[[operators[10],"pop",operators[10],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0) - tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0005532683067148436

# %%
model=[[operators[11],"pop",operators[11],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0) - acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0) - asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0) - atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018001857476440105

# %%
model=[[operators[14],"pop",operators[14],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0) - tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0001969047478953895

# %%
model=[[operators[15],"pop",operators[15],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0) - log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'sqrt':1,'arccos':1,'arcsin':1,'log':1,'inv':0.001183886,'exp':0.00085393,'tan':0.00055326,'tanh':0.000196904,'arctan':0.0001800,'sin':0.00014554,'sqrd':0.00002125,'cos':0.00001918}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Subtraction")
plt.title("Subtraction Operator Combinations [-1,1]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(-1,1,0.0013)
np.random.shuffle(y)
y
# Out:
# array([ 0.2103,  0.846 , -0.8011, ...,  0.4261, -0.6412,  0.0829])

# %%
inputData=np.array([np.arange(-1,1,.0013),y])
response=inputData[0]*inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0)*exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009388313218823412

# %%
model=[[operators[5],"pop",operators[5],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2*x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0007081572396683499

# %%
model=[[operators[6],"pop",operators[6],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0)*sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[7],"pop",operators[7],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# 1/(x0*x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.410330223308678e-05

# %%
model=[[operators[8],"pop",operators[8],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0)*cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0002510592917422566

# %%
model=[[operators[9],"pop",operators[9],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0)*sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00031502335547545327

# %%
model=[[operators[10],"pop",operators[10],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0)*tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0018988217109216284

# %%
model=[[operators[11],"pop",operators[11],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0)*acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0)*asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0)*atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0003838546989994611

# %%
model=[[operators[14],"pop",operators[14],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0)*tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00039211334683797526

# %%
model=[[operators[15],"pop",operators[15],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0)*log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'sqrt':1,'arccos':1,'arcsin':1,'log':1,'tan':0.0018988,'exp':0.000938831,'sqrd':0.00070815,'tanh':0.00039211,'arctan':0.000383,'sin':0.00031502,'cos':0.0002510,'inv':0.0000641}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Multiplication")
plt.title("Multiplication Operator Combinations [-1,1]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(-1,1,0.0013)
np.random.shuffle(y)
y
# Out:
# array([-0.8856,  0.0075, -0.3279, ...,  0.9201, -0.3864, -0.311 ])

# %%
inputData=np.array([np.arange(-1,1,.0013),y])
response=inputData[0]*inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0)*exp(-x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009219249333807903

# %%
model=[[operators[5],"pop",operators[5],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2/x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 3.672701734651808e-06

# %%
model=[[operators[6],"pop",operators[6],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0)/sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[7],"pop",operators[7],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0020304127915705466

# %%
model=[[operators[8],"pop",operators[8],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0)/cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018367131180381548

# %%
model=[[operators[9],"pop",operators[9],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0)/sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.002562222443978962

# %%
model=[[operators[10],"pop",operators[10],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0)/tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0019372141624706652

# %%
model=[[operators[11],"pop",operators[11],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0)/acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0)/asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0)/atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00272312074324925

# %%
model=[[operators[14],"pop",operators[14],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0)/tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.002682188974639263

# %%
model=[[operators[15],"pop",operators[15],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0)/log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'sqrt':1,'arccos':1,'arcsin':1,'log':1,'arctan':0.002723,'tanh':0.00268218,'sin':0.0025622,'inv':0.0020304,'tan':0.0019372,'exp':0.00092192,'cos':0.0001836,'sqrd':0.00000367}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Division")
plt.title("Division Operator Combinations [-1,1]")
plt.yscale("log")
plt.show()

# %% [markdown]
# # Range [1,1000]

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(1,1000,0.13)
np.random.shuffle(y)
y
# Out:
# array([362.14, 511.51, 356.94, ..., 416.35, 706.51, 499.03])

# %%
inputData=np.array([np.arange(1,1000,.13),y])
response=inputData[0]+inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0) + exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[5],"pop",operators[5],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2 + x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00033236908362623295

# %%
model=[[operators[6],"pop",operators[6],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0) + sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[7],"pop",operators[7],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# 1/x1 + 1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014982431986147995

# %%
model=[[operators[8],"pop",operators[8],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0) + cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018394008492967996

# %%
model=[[operators[9],"pop",operators[9],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0) + sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018503371381093433

# %%
model=[[operators[10],"pop",operators[10],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0) + tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00017180080636280194

# %%
model=[[operators[11],"pop",operators[11],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0) + acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0) + asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0) + atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0025993932234996365

# %%
model=[[operators[14],"pop",operators[14],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0) + tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0025147011746587252

# %%
model=[[operators[15],"pop",operators[15],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0) + log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'exp':1,'sqrt':1,'arccos':1,'arcsin':1,'log':1,'arctan':0.00259939,'tanh':0.0025147,'inv':0.00149824,'sqrd':0.000332369,'sin':0.0001850337,'cos':0.00018394,'tan':0.0001718008}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Addition")
plt.title("Addition Operator Combinations [1,1000]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(1,1000,0.13)
np.random.shuffle(y)
y
# Out:
# array([119.43,  43.51, 787.76, ..., 840.93, 446.51, 111.24])

# %%
inputData=np.array([np.arange(1,1000,.13),y])
response=inputData[0]-inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0) - exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[5],"pop",operators[5],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2 - x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00034196516214402017

# %%
model=[[operators[6],"pop",operators[6],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0) - sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[7],"pop",operators[7],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# -1/x1 + 1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.001645778655623534

# %%
model=[[operators[8],"pop",operators[8],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0) - cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018944535840885622

# %%
model=[[operators[9],"pop",operators[9],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0) - sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0001722450858190399

# %%
model=[[operators[10],"pop",operators[10],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0) - tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00016877443970040242

# %%
model=[[operators[11],"pop",operators[11],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0) - acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0) - asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0) - atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.002581413798086814

# %%
model=[[operators[14],"pop",operators[14],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0) - tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0024269896919351707

# %%
model=[[operators[15],"pop",operators[15],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0) - log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'exp':1,'sqrt':1,'arccos':1,'arcsin':1,'log':1,'arctan':0.0025814,'tanh':0.002426,'inv':0.00164577,'sqrd':0.00034196,'cos':0.00018944,'sin':0.000172245,'tan':0.00016877}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Subtraction")
plt.title("Subtraction Operator Combinations [1,1000]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(1,1000,0.13)
np.random.shuffle(y)
y
# Out:
# array([514.89, 396.72, 539.2 , ..., 804.27, 364.09, 728.87])

# %%
inputData=np.array([np.arange(1,1000,.13),y])
response=inputData[0]*inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0)*exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[5],"pop",operators[5],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2*x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0008052196869528089

# %%
model=[[operators[6],"pop",operators[6],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0)*sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[7],"pop",operators[7],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# 1/(x0*x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0005216367645403269

# %%
model=[[operators[8],"pop",operators[8],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0)*cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018968102142738724

# %%
model=[[operators[9],"pop",operators[9],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0)*sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018189663081226532

# %%
model=[[operators[10],"pop",operators[10],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0)*tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00019979789926637614

# %%
model=[[operators[11],"pop",operators[11],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0)*acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0)*asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0)*atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0012664397214592826

# %%
model=[[operators[14],"pop",operators[14],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0)*tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0013712603260768626

# %%
model=[[operators[15],"pop",operators[15],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0)*log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'exp':1,'sqrt':1,'arccos':1,'arcsin':1,'log':1,'tanh':0.00137126,'arctan':0.00126643,'sqrd':0.00080521,'inv':0.00052163,'tan':0.000199797,'cos':0.0001896,'sin':0.00018189}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Multiplication")
plt.title("Multiplication Operator Combinations [1,1000]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(1,1000,0.13)
np.random.shuffle(y)
y
# Out:
# array([261.65, 739.14, 357.85, ..., 475.5 ,  42.73, 662.83])

# %%
inputData=np.array([np.arange(1,1000,.13),y])
response=inputData[0]/inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0)*exp(-x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[5],"pop",operators[5],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2/x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.02668548425412301

# %%
model=[[operators[6],"pop",operators[6],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0)/sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[7],"pop",operators[7],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 7.961579365834723e-05

# %%
model=[[operators[8],"pop",operators[8],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0)/cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.004365629519147462

# %%
model=[[operators[9],"pop",operators[9],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0)/sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009290566461165301

# %%
model=[[operators[10],"pop",operators[10],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0)/tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0012617950001196296

# %%
model=[[operators[11],"pop",operators[11],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0)/acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0)/asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0)/atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.02759479407087444

# %%
model=[[operators[14],"pop",operators[14],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0)/tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.029915982344562386

# %%
model=[[operators[15],"pop",operators[15],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0)/log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'exp':1,'sqrt':1,'arccos':1,'arcsin':1,'log':1,'tanh':0.029915,'arctan':0.0275947,'sqrd':0.0266854,'cos':0.00436562,'tan':0.001261795,'sin':0.00092905,'inv':0.000079157}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Division")
plt.title("Division Operator Combinations [1,1000]")
plt.yscale("log")
plt.show()

# %% [markdown]
# # Range [100,105]

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(100,105,0.0013)
np.random.shuffle(y)
y
# Out:
# array([104.1912, 100.1027, 104.0768, ..., 102.3985, 101.9968, 103.5932])

# %%
inputData=np.array([np.arange(100,105,.0013),y])
response=inputData[0]+inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0) + exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[5],"pop",operators[5],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2 + x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.266403818456107e-05

# %%
model=[[operators[6],"pop",operators[6],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0) + sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.315263827931222e-05

# %%
model=[[operators[7],"pop",operators[7],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# 1/x1 + 1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.726159584134879e-05

# %%
model=[[operators[8],"pop",operators[8],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0) + cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0010676325447133814

# %%
model=[[operators[9],"pop",operators[9],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0) + sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014633352482729062

# %%
model=[[operators[10],"pop",operators[10],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0) + tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00021980445999245977

# %%
model=[[operators[11],"pop",operators[11],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0) + acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0) + asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0) + atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.678589819397984e-05

# %%
model=[[operators[14],"pop",operators[14],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0) + tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[15],"pop",operators[15],operators[1]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0) + log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.430528416089597e-05

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'exp':1,'arccos':1,'arcsin':1,'tanh':1,'sin':0.00146333,'cos':0.00106763,'tan':0.000219804,'inv':0.0000672615,'arctan':0.000066785,'log':0.000064305,'sqrt':0.000063152,'sqrd':0.000062664}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Addition")
plt.title("Addition Operator Combinations [100,105]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(100,105,0.0013)
np.random.shuffle(y)
y
# Out:
# array([101.1219, 104.9127, 104.2861, ..., 104.9335, 103.8389, 101.8681])

# %%
inputData=np.array([np.arange(100,105,.0013),y])
response=inputData[0]-inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0) - exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[5],"pop",operators[5],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2 - x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.323112914941168e-05

# %%
model=[[operators[6],"pop",operators[6],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0) - sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.218779223982616e-05

# %%
model=[[operators[7],"pop",operators[7],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# -1/x1 + 1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.59089129829674e-05

# %%
model=[[operators[8],"pop",operators[8],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0) - cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0010826124419057342

# %%
model=[[operators[9],"pop",operators[9],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0) - sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014484659946275525

# %%
model=[[operators[10],"pop",operators[10],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0) - tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00017393096055953551

# %%
model=[[operators[11],"pop",operators[11],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0) - acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0) - asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0) - atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.752489897568372e-05

# %%
model=[[operators[14],"pop",operators[14],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0) - tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[15],"pop",operators[15],operators[2]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0) - log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.331511138155083e-05

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'exp':1,'arccos':1,'arcsin':1,'tanh':1,'sin':0.0014484,'cos':0.0010826,'tan':0.000173930,'arctan':0.0000675248,'inv':0.000065908,'log':0.000063315,'sqrd':0.0000632311,'sqrt':0.0000621877}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Subtraction")
plt.title("Subtraction Operator Combinations [100,105]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(100,105,0.0013)
np.random.shuffle(y)
y
# Out:
# array([103.7011, 100.819 , 104.1626, ..., 104.7606, 100.0884, 101.2688])

# %%
inputData=np.array([np.arange(100,105,.0013),y])
response=inputData[0]*inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0)*exp(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[5],"pop",operators[5],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2*x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.723828990746438e-05

# %%
model=[[operators[6],"pop",operators[6],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0)*sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.550280086951538e-05

# %%
model=[[operators[7],"pop",operators[7],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# 1/(x0*x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 7.740119227459932e-05

# %%
model=[[operators[8],"pop",operators[8],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0)*cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0005260950177325569

# %%
model=[[operators[9],"pop",operators[9],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0)*sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0007414996891940772

# %%
model=[[operators[10],"pop",operators[10],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0)*tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 7.913882477669213e-05

# %%
model=[[operators[11],"pop",operators[11],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0)*acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0)*asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0)*atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 7.111877422262624e-05

# %%
model=[[operators[14],"pop",operators[14],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0)*tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[15],"pop",operators[15],operators[3]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0)*log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.705431834375764e-05

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'exp':1,'arccos':1,'arcsin':1,'tanh':1,'sin':0.0007414996,'cos':0.00052609,'tan':0.0000791388,'inv':0.0000774011,'arctan':0.00007111877,'sqrd':0.0000672382,'log':0.0000670543,'sqrt':0.0000655028008}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Multiplication")
plt.title("Multiplication Operator Combinations [100,105]")
plt.yscale("log")
plt.show()

# %%
from StackGP import *
import numpy as np

# %%
operators=allOps()

# %%
y=np.arange(100,105,0.0013)
np.random.shuffle(y)
y
# Out:
# array([102.0345, 102.6793, 101.5106, ..., 102.6377, 100.3458, 103.5984])

# %%
inputData=np.array([np.arange(100,105,.0013),y])
response=inputData[0]/inputData[1]

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[4],"pop",operators[4],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# exp(x0)*exp(-x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.004271223083293899

# %%
model=[[operators[5],"pop",operators[5],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2/x1**2

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.604474242569142e-05

# %%
model=[[operators[6],"pop",operators[6],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sqrt(x0)/sqrt(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.323032830902615e-05

# %%
model=[[operators[7],"pop",operators[7],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x1/x0

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 7.751881922333709e-05

# %%
model=[[operators[8],"pop",operators[8],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# cos(x0)/cos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00020588396259114183

# %%
model=[[operators[9],"pop",operators[9],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# sin(x0)/sin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0003425416035485

# %%
model=[[operators[10],"pop",operators[10],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tan(x0)/tan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0002258615361786184

# %%
model=[[operators[11],"pop",operators[11],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# acos(x0)/acos(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[12],"pop",operators[12],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# asin(x0)/asin(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[13],"pop",operators[13],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# atan(x0)/atan(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.691211468351549e-05

# %%
model=[[operators[14],"pop",operators[14],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# tanh(x0)/tanh(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[15],"pop",operators[15],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# log(x0)/log(x1)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.531166514085941e-05

# %%
import numpy as np
import matplotlib.pyplot as plt 

 
# creating the dataset
data = {'arccos':1,'arcsin':1,'tanh':1,'exp':0.00427122,'sin':0.0003425,'tan':0.00022586,'cos':0.00020588,'inv':0.0000775188,'arctan':0.00006691211,'sqrd':0.0000660447,'log':0.0000653116,'sqrt':0.0000632303}
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.4)

plt.xlabel("Functions")
plt.ylabel("Division")
plt.title("Division Operator Combinations [100,105]")
plt.yscale("log")
plt.show()

# %%
operators
# Out:
# [<function StackGP.protectDiv(a, b)>,
#  <function StackGP.add(a, b)>,
#  <function StackGP.sub(a, b)>,
#  <function StackGP.mult(a, b)>,
#  <function StackGP.exp(a)>,
#  <function StackGP.sqrd(a)>,
#  <function StackGP.sqrt(a)>,
#  <function StackGP.inv(a)>,
#  <function StackGP.cos(a)>,
#  <function StackGP.sin(a)>,
#  <function StackGP.tan(a)>,
#  <function StackGP.arccos(a)>,
#  <function StackGP.arcsin(a)>,
#  <function StackGP.arctan(a)>,
#  <function StackGP.tanh(a)>,
#  <function StackGP.log(a)>,
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop']

# %%
model=[[operators[7],operators[5],operators[7],operators[8],operators[7]],[variableSelect(0)]]

# %%
printGPModel(model)
# Out:
# 1/cos(x0**2)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009039159243568373

# %%
model=[[operators[5],"pop",operators[7],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x0**2*x1

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 9.894882550595465e-05

# %%
model=[[operators[4],"pop",operators[7],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
printGPModel(model)
# Out:
# x1*exp(x0)

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[9],"pop",operators[8],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.001770377427012182

# %%
model=[[operators[9],"pop",operators[8],operators[10]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00018384539028734967

# %%
#Tan + Inverse [1,1000]

# %%
model=[[operators[7],"pop",operators[7],operators[10]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.01281291333663323

# %%
model=[[operators[7],"pop",operators[7],operators[7]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00030570562581955

# %%
model=[[operators[10],"pop",operators[10],operators[10]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0022125041213271906

# %%
model=[[operators[4],"pop",operators[4],operators[10]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[10],"pop",operators[10],operators[7]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0011054373349137709

# %%
model=[[operators[7],"pop",operators[7],operators[8]],[variableSelect(0),variableSelect(1)]]

# %%
#Inv + Cos [1,1000]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.021686153358060983

# %%
model=[[operators[7],"pop",operators[7],operators[9]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.009132860704334257

# %%
model=[[operators[8],"pop",operators[8],operators[7]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.001573760475371772

# %%
model=[[operators[8],"pop",operators[9],operators[7]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.004837767236404229

# %%
model=[[operators[6],"pop",operators[6],operators[6]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009304011893524975

# %%
model=[[operators[6],"pop",operators[7],operators[8]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009347466483772104

# %%
model=[[operators[8],"pop",operators[8],operators[4]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0011523928196859163

# %%
model=[[operators[6],"pop",operators[7],operators[9]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009146248867370506

# %%
model=[[operators[4],"pop",operators[4],operators[7]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0017662597063608921

# %%
model=[[operators[7],"pop",operators[7],operators[4]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009207217829341812

# %%
model=[[operators[15],"pop",operators[15],operators[15]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009165504657776294

# %%
#sin + inv

# %%
model=[[operators[7],"pop",operators[7],operators[9]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00902315172635418

# %%
model=[[operators[9],"pop",operators[9],operators[7]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0007950031758095006

# %%
model=[[operators[7],operators[7],operators[9]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00017980639868857298

# %%
model=[[operators[7],operators[8],operators[9]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 1.1578688545483375e-05

# %%
model=[[operators[8],operators[9],operators[10]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00017643209299798068

# %%
model=[[operators[9],"pop",operators[8]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00017381587116745243

# %%
model=[[operators[8],"pop",operators[5]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 6.684831317760595e-05

# %%
model=[[operators[7],operators[5],operators[8],operators[9],operators[7]],[variableSelect(0)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009323079819962325

# %%
model=[[operators[7],operators[5],operators[8],operators[9]],[variableSelect(0)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0007435064607392253

# %%
model=[[operators[7],operators[15],operators[6],operators[9]],[variableSelect(0)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[15],operators[6],operators[9]],[variableSelect(0)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[6],operators[9],operators[14]],[variableSelect(0)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[6],operators[5],operators[15]],[variableSelect(0)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
model=[[operators[5],"pop",operators[5],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
model=[[operators[13],"pop",operators[13],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
#tanh [1,1000]

# %%
model=[[operators[14],"pop",operators[14],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0005402907062584899

# %%
0.029915982344562386
# Out:
# 0.029915982344562386

# %%
model=[[operators[14],"pop",operators[13]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014010758042872517

# %%
model=[[operators[14],"pop",operators[13],operators[7]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0016837716175985584

# %%
model=[[operators[14],"pop",operators[13],operators[7],operators[8]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00024970675287973326

# %%
model=[[operators[7],"pop",operators[8],operators[0]],[variableSelect(0),variableSelect(1)]]

# %%
totalSharpness(model,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.001227441981440827

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sqrt at 0x000001E8B7EBECA0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>], dtype=object),
#  [3.141592653589793,
#   28.27021055587019,
# ...

# %%
printGPModel(randomModel)
# Out:
# asin(cos(sin(sqrt(exp(1/log(2.71828182845905*x0**(1/4)*(3.14159265358979 - 3.99934906373168*I)))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function inv at 0x000001E8B7EBEDE0>], dtype=object),
#  [3, 10.94286587890262, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1/log(0.498404210748626*sqrt(cos(3)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop'], dtype=object),
#  [13.636510058481516,
#   2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(asin(24.6122358468973*(0.201569336365509*x1 + 1)**2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', <function sqrd at 0x000001E8B7EBED40>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>], dtype=object),
#  [3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# tan(tanh(1.77245385090552*sqrt(0.318309886183791*atan(x1**2) + 1))**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 4.037512337287569e-05

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
# ...

# %%
printGPModel(randomModel)
# Out:
# sin(cos(0.367879457455811*exp(asin(log(2.71828182845905*atan(5.1197940342397*(x0 + 0.103059771974513 + 0.0407728271897107*I)**2))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(3,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop'], dtype=object),
#  [-3,
#   2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   19.790129156035725],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(-2*asin(1.48510454461503*x0*x1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(3,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop'], dtype=object),
#  [2,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
# ...

# %%
printGPModel(randomModel)
# Out:
# atan(log(2)*tanh(sin(tanh(atan(acos(x1)) + acos(exp(-5.43656365691809/pi)))))**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(1,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>], dtype=object),
#  [17.642603670771734, 3.141592653589793, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# asin(0.355869280198206 - sin(1/log(asin(1.56649736903682*sqrt(I))))/sqrt(1 + sin(1/log(asin(1.56649736903682*sqrt(I))))**2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(1,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function protectDiv at 0x000001E8B0D99E40>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop', 'pop',
#         'pop'], dtype=object),
#  [0, 2.718281828459045, 3.141592653589793, -3, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# asin(1.24557318006278 + I*pi)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sqrt at 0x000001E8B7EBECA0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
# ...

# %%
printGPModel(randomModel)
# Out:
# 22.2492381060067*sqrt(1/acos(-x0**2 + x0 - 1/(cos(sin(sqrt(cos(sqrt(1 - 0.5/atan(tanh(x1))))))) + 0.410781290502909)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arctan at 0x000001E8B7EBF1A0>], dtype=object),
#  [28.43154753896207],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1.48179221251881

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function cos at 0x000001E8B7EBEF20>,
# ...

# %%
printGPModel(randomModel)
# Out:
# sqrt(2)*sqrt(-sin(x0 + 1.5707963267949 + 0.985627226308829*pi - 23.9426869227916*I)/cos(tanh(3/tan(cos(exp(-asin(0.907539902505364*tanh(cos(x1)/2))))))))/2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function log at 0x000001E8B7EBF2E0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(1/asin(tan(sqrt(x1))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# atan(atan(cos(x0 + log(x0)**2)))**2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   17.993815104987014,
#   2.718281828459045,
# ...

# %%
printGPModel(randomModel)
# Out:
# 18.0308268020281*acos(x0) - 1.00765470210576 - 0.190804432769764*I

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(3,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function cos at 0x000001E8B7EBEF20>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         'pop', 'pop', 'pop', <function mult at 0x000001E8B7EBEAC0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# (1.5707963267949 - 1.65745445415308*I)*atan(sqrt(1 - log(sin(x1))**2)/(log(sin(x1))*atan(16.1993418504831 - 1/(x0*atan(11.9530977415207/asin(acos(atan(cos(3))**(-2))))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>], dtype=object),
#  [-1,
#   3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(cos(acos(x1 + 0.101321183642338)/sqrt(1 - acos(x1 + 0.101321183642338)**2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(1 - cos(tan(1/cos(cos(asin(x1)/x0))))**2)/cos(tan(1/cos(cos(asin(x1)/x0))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arccos at 0x000001E8B7EBF060>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1/tan(x0 + sqrt(log(sin(sqrt(1 - x1**2)/x1))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
#  [-2, 2.718281828459045, -1],
#  []]

# %%
printGPModel(randomModel)
# Out:
# acos(tan((pi/4 + 1.0)*exp(-2))**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function exp at 0x000001E8B7EBEB60>], dtype=object),
#  [21.55230746042822,
#   2.718281828459045,
#   3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(tanh(asin(sin(464.50195686883/(2.92228236532228 - 1.64872127070013*x0)))**(-2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0015163843122083702

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function mult at 0x000001E8B7EBEAC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop', 'pop',
#         'pop', 'pop', <function log at 0x000001E8B7EBF2E0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# 0.680185523112781*I*sqrt(log(log(-6.51665712712004*I)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function tanh at 0x000001E8B7EBF240>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>], dtype=object),
#  [3.141592653589793, 2.718281828459045, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 0.995496093069520

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1/log(tanh(sqrt(sin(log(acos(x1**3))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sin at 0x000001E8B7EBEE80>], dtype=object),
#  [17.165352078084098],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -0.993576256800691

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arccos at 0x000001E8B7EBF060>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# tanh(0.367879441171442*asin(tanh(1/atan(acos(2))))/cos(tan(sin(tanh(asin(tan(tan(x1 + log(x0)))))) + 1.5707963267949 - 1.65745445415308*I)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function add at 0x000001E8B58C6840>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function tan at 0x000001E8B7EBEFC0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# asin(sin(tanh(10.8782851738243*tan(sqrt(x0 + cos(log(acos(acos(exp((39.4784176043574 - asin(2))*cos(sqrt(3)*sqrt(-x1)/3)/2)))))*tan(x0))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function add at 0x000001E8B58C6840>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793,
#   3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   27.27475915645291],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(acos(cos(tan(log(sin(log(tanh(0.0366639351153871*x0 + 3.14159265358979)) + 3.14159265358979 + 1/cos(x0)))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function add at 0x000001E8B58C6840>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
# ...

# %%
printGPModel(randomModel)
# Out:
# sin((x0 + 2.71828182845905)/tanh(acos(tan(9.86960440108936*sqrt(0.0102659822546843 - (0.318309886183791*x1 - 1)**2)*sin(1)**2))*atan(x1 + 1.22464679914735e-16)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', 'pop', 'pop', 'pop', 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function add at 0x000001E8B58C6840>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# asin(sin(cos(24.6966747650633/(3*tan(exp(1/sqrt(cos(sin(1.64872127070013*x1))**4 + 1))) + 2.71828182845905))**2)) - 1

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0013746263025861878

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop'], dtype=object),
#  [2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   -1,
#   3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# tanh(asin(acos(exp(0.318309886183791*tanh(acos(1.64872127070013 - tan(x1)**(1/4)))/(log(pi/4) + I*pi)))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop'],
#        dtype=object),
#  [3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 3.14159265358979*exp(-1/x0)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', <function arcsin at 0x000001E8B7EBF100>,
#         'pop', <function sub at 0x000001E8B7EBEA20>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# 0

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function arccos at 0x000001E8B7EBF060>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tan at 0x000001E8B7EBEFC0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sin(sqrt(tanh(1/cos(tan(sin(sin(asin(acos(x0))**2)))))))/sqrt(1 - sin(sqrt(tanh(1/cos(tan(sin(sin(asin(acos(x0))**2)))))))**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>,
#         <function add at 0x000001E8B58C6840>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function add at 0x000001E8B58C6840>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# log(acos(0.761594155955765 - tan(tan(tanh(asin(exp(asin((-sin(x1) + tanh(x0))**2)) + zoo))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>], dtype=object),
#  [15.605283030174652, 18.152505871860676],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -0.404279986599586

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop'], dtype=object),
#  [2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1.0*x1

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014615900084333682

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop'], dtype=object),
#  [3,
#   3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# acos(-x0 - 0.141592653589793)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# -sin(-1.5707963267949 + 13.9309278951046*I + 1/tanh(atan(tan(cos(2*exp(-tanh(sqrt(1 - atan(exp(-asin(x0/acos(-3))))**2)/atan(exp(-asin(x0/acos(-3))))))))**2)**2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# asin(acos(15.5526933973581*asin(2*cos(1/sqrt(x1*sin(x0**(-2)) - acos(exp(-1)))))**2/acos(sin(exp(x0)))**2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>], dtype=object),
#  [1, <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(atan(cos(1)**2*cos(log(x0))**2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# -tan(-1.52075325792167*tan(tanh(x0)) + 1.52075325792167*asin(1.08801300922421*x1*asin(sqrt(x0))) + 9.71617787749309)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function cos at 0x000001E8B7EBEF20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function add at 0x000001E8B58C6840>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [15.046070408068317,
#   24.86350124842148,
#   20.30980110871802,
#   3,
#   13.443618814474638,
#   3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 26.9238248515983 - tanh(asin(20.309801108718 - sqrt(3)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sin at 0x000001E8B7EBEE80>], dtype=object),
#  [20.524482177882188, 1],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -0.449911639943999

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop', 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function add at 0x000001E8B58C6840>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sub at 0x000001E8B7EBEA20>,
# ...

# %%
printGPModel(randomModel)
# Out:
# exp(-x0 - 233.590479935675*exp(cos(tanh(x0))**4) + pi/2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0027189806096021623

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function protectDiv at 0x000001E8B0D99E40>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function protectDiv at 0x000001E8B0D99E40>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   17.569885533479173,
#   2.718281828459045,
#   29.938503931690576,
#   19.56386922828368,
#   25.66392490525358],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -2.09482733266373*exp(acos(29.9385039316906*acos(0.0569155671557742*x0) - 81.3812912087642))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>, 3],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sin(sin(exp(atan(x1) - tan(log(3)))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.002420228957615512

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', 'pop', <function log at 0x000001E8B7EBF2E0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>], dtype=object),
#  [20.641698020229814, 3.141592653589793, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -2.09601225188407

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', 'pop', 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [3.141592653589793, 3.141592653589793, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 3.28731907571652

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>], dtype=object),
#  [-2, 3.141592653589793, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(exp(0.410781290502909*tan(sin(tan(0.318309886183791 - atan(2))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function protectDiv at 0x000001E8B0D99E40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arcsin at 0x000001E8B7EBF100>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# I*asinh(1/sqrt(-log(cos(sin(1)))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# I + 24.8443635133598*asin(sin(sqrt(0.86511066769907 + 0.202279045843566*I)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function mult at 0x000001E8B7EBEAC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function tanh at 0x000001E8B7EBF240>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045,
#   -3,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   16.930267504407563,
#   3,
#   2],
#  []]

# %% [raw]
# printGPModel(randomModel)

# %%
printGPModel(randomModel)
# Out:
# tanh(1/sin(cos(1719.80374662479*(-x0 - 0.0590658121461851*sin(0.906093942819682*x1))**2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0017897429326862104

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function tanh at 0x000001E8B7EBF240>], dtype=object),
#  [15.799156829942113, -2, -1],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -tanh(tan(1 + 0.999999999999962*sin(log(2) + I*pi)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
# ...

# %%
printGPModel(randomModel)
# Out:
# log(-log(tanh(log(tanh(cos(acos(acos(-3)*atan(x0)**2) - 1/x1))))) + sin(x0))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function add at 0x000001E8B58C6840>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>], dtype=object),
#  [27.078295023578573, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(0.915448960711802 - 0.255248163357155*I)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>], dtype=object),
#  [13.51032597197075, 0],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(cos(tan(1)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# 1/tan(tanh(asin(asin(sin(sqrt(cos(0.541939139740503*log(-0.985032937281266/x0) - 0.494104293451889)/x0)))**2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [-1, 3, 26.105929265471893],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 25.1059292654719 - cos(3)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sqrd at 0x000001E8B7EBED40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop'], dtype=object),
#  [3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
# ...

# %%
printGPModel(randomModel)
# Out:
# -1/tan(tanh(x0 - 9.86960440108936)/cos(sqrt(1 - 1/cos(tanh(1))**2)*sin(x1)*cos(tanh(1))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# atan(asin(1/log(-x1/tanh(cos(x0/sqrt(x1**2 + 1))) - 0.769507817065694 + acos(acos(4.81047738096535*exp(-1.65745445415308*I))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# acos(asin(0.0705167340804354*exp((1 - tan(sqrt(sin(sin(tan(sqrt(tan(16.4737452788117*x0)))))))**2)**(1/4)))/acos(acos((6.35069854163047*pi - 10.4770952725976*I)**2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tanh at 0x000001E8B7EBF240>, 'pop', 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793],
#  []]

# %%
# One decimal place deep

# %%
printGPModel(randomModel)
# Out:
# sqrt(1 - cos(tanh(x0) - 23.1406926327793)**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.1617282131810319

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function mult at 0x000001E8B7EBEAC0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop', 'pop'],
#        dtype=object),
#  [2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# asin(2.71828182845905*x0)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop'], dtype=object),
#  [21.534564399761763,
#   26.068356603681305,
# ...

# %%
printGPModel(randomModel)
# Out:
# 3.76226693671974*I + 461800.728073225/cos(atan(x0) - 1.27176068112324*I)**2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>], dtype=object),
#  [3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -1.00000000000000

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrt at 0x000001E8B7EBECA0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function tan at 0x000001E8B7EBEFC0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
# ...

# %%
printGPModel(randomModel)
# Out:
# tan(log(atan(atan(acos(exp(sqrt(x1)) + 1/tanh(23.0448364912543*sqrt(0.00188301048344435*x1 - 0.00188301048344435*exp(x0) - 1)))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>, 'pop', 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# (x0 + 2.71828182845905)/tanh(sqrt(1 - x0**2)/x0)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop', 'pop',
#         'pop', 'pop', <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         'pop', <function sqrt at 0x000001E8B7EBECA0>], dtype=object),
#  [3.141592653589793, 3.141592653589793, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(atan(tanh(0.191770867827359*(1.5707963267949 + 1.65745445415308*I))**(-4)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop',
#         'pop', 'pop', 'pop', <function arctan at 0x000001E8B7EBF1A0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arcsin at 0x000001E8B7EBF100>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# asin(1/sqrt(log(x1)**2 + 1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrt at 0x000001E8B7EBECA0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop', 'pop', 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# nan

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [10.783185772325712,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   25.50990713148213,
#   3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(tanh(x1 + 10.7831857723257)) - sin(0.039200456310791*x1/tanh(0.318309886183791*tanh(x0 + 3.14159265358979)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0015908302230961818

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop'],
#        dtype=object),
#  [-3,
#   24.912049288784267,
#   2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -atan(asin(sin(-x1 + sin(sin(3)) + 2.75842304640574)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0076742386027761084

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>, 'pop'], dtype=object),
#  [18.810313846395005,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 18.810313846395 - x0

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0015034436661858226

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014483853047632168

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>, 'pop'], dtype=object),
#  [18.810313846395005,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 18.810313846395 - x0

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arcsin at 0x000001E8B7EBF100>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function log at 0x000001E8B7EBF2E0>], dtype=object),
#  [10.035813782459396],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(1.47801399333852*I)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function protectDiv at 0x000001E8B0D99E40>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop'],
#        dtype=object),
#  [2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# cos((2.71828182845904 + 4.0647844411571e-16*I)**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
# ...

# %%
printGPModel(randomModel)
# Out:
# cos(sqrt(1 - asin(7.38905609893065/tan(0.65489651381078*tanh(31.4479692279189 - 15.7239846139595*acos(exp(sqrt(1 - log(pi/4)**2))))))**2)/asin(7.38905609893065/tan(0.65489651381078*tanh(31.4479692279189 - 15.7239846139595*acos(exp(sqrt(1 - log(pi/4)**2)))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop'], dtype=object),
#  [28.372123095155786, 0],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 0.187738819325831

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop', 'pop'],
#        dtype=object),
#  [2.718281828459045,
#   3.141592653589793,
#   3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -x1 + exp(x0*acos(sqrt(1 - 0.638317429394233*I)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# tanh(exp(sqrt(acos(asin(exp(exp(1.77245385090552*sqrt(x0) + cos(2)))))))) + 0.934648878900645*sqrt(asin(atan(exp(0.318309886183791*atan(27.2650297871222*asin(sin((1.28568474161116 - 0.552917418146371*I)**2)))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# tanh(sqrt(x1/cos(8.16339016751341*exp(-2.71828182845905*exp(tan(x1**2)**2) + 2.71828182845905*asin(x0)))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   16.364040856782157,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(-2/x0)*tan(0.0611096005413324*asin(asin(x1)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function mult at 0x000001E8B7EBEAC0>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   18.004354976219858,
#   12.887880077346352],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 18.0043549762199*x0 - 12.8878800773464

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014862505185555006

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop', 'pop'],
#        dtype=object),
#  [0, 3],
#  []]

# %%
printGPModel(randomModel)
# Out:
# pi/2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# asin(log(exp(sqrt(asin(1.77245385090552*asin(x0**2)))) + tan(tanh(log(1.57834101852648*I)**2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>, 'pop'], dtype=object),
#  [28.31411083176669],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 3.34336029634505

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function add at 0x000001E8B58C6840>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function cos at 0x000001E8B7EBEF20>], dtype=object),
#  [2,
#   2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# cos(x1**2*(x0 + 4.71828182845904))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0006227340317236767

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tan at 0x000001E8B7EBEFC0>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
#  [1],
#  []]

# %%
printGPModel(randomModel)
# Out:
# acos(tan(1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# x0

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014666170562288694

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>], dtype=object),
#  [10.601749245866017,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1/sqrt(1 + (0.458689919957068 - 1.93894276208138*I)**2/x0**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function inv at 0x000001E8B7EBEDE0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function add at 0x000001E8B58C6840>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# 1.07107548307291*(-(-0.333333333333333*sqrt(x0) - 0.333333333333333*x0 + 1)**(1/4) + 0.498743338451332 + 0.759835685651593*asin(3.14159265358979 - tanh(1)))**(1/4)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function add at 0x000001E8B58C6840>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arctan at 0x000001E8B7EBF1A0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# sqrt(-sin(sin(sin(x0 - 0.318309886183791*atan(1.15572734979092*sqrt((0.318309886183791*log(-31.2577611267433 + 15.1542622414793/x1) + 1)**2)))))/sqrt(sin(sin(sin(x0 - 0.318309886183791*atan(1.15572734979092*sqrt((0.318309886183791*log(-31.2577611267433 + 15.1542622414793/x1) + 1)**2)))))**2 + 1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793,
#   2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# atan(6.04565683096567*sqrt(-atan(x1**2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045,
#   -2],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -tan(0.367879441171442*x0**2*tanh(2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.00022336708066901363

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function arctan at 0x000001E8B7EBF1A0>, 'pop'],
#        dtype=object),
#  [3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1.26262725567891

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   -1,
# ...

# %%
printGPModel(randomModel)
# Out:
# x1*acos(-x0 + log(sin(exp(acos(atan(sqrt(x0**2)))))) + 1 + 1/(x0 + 21.2737151964245*log(2.71828182845905/x1)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function add at 0x000001E8B58C6840>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
#  [-2, 3.141592653589793, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# acos(exp(-atan(2)) - atan(tan(0.0764394453119813 - I*pi)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function exp at 0x000001E8B7EBEB60>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# asin(tanh(exp(2*x0))) - atan(acos(log(2.71828182845905/x0) + atan(exp(x0))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', <function arcsin at 0x000001E8B7EBF100>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function add at 0x000001E8B58C6840>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
#  [28.409293832856406,
# ...

# %%
printGPModel(randomModel)
# Out:
# acos(exp(-3.14159265358979*sqrt((0.318309886183791*exp(sin(x1)) + 0.318309886183791*log((28.4092938328564 - cos(x1 - 1.72356295537669 + 0.277993365150752*I))*exp(-1)) + 1)**2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
#  [0, 3.141592653589793, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# pi/2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   12.610178280273335],
#  []]

# %%
printGPModel(randomModel)
# Out:
# x1 - 1/sqrt(1 + (0.020354555158807 - 0.864183062766729*I)**4)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>], dtype=object),
#  [3.141592653589793, 3],
#  []]

# %%
printGPModel(randomModel)
# Out:
# tanh(cos(1/atan(atan(asin(exp(1/sqrt(1 + tanh(tan(exp(-tan(sin(exp(3)) - 1.81152627246085*I))))**2)))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function add at 0x000001E8B58C6840>, 'pop', 'pop', 'pop',
#         'pop', <function log at 0x000001E8B7EBF2E0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop', 'pop',
#         'pop', <function inv at 0x000001E8B7EBEDE0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# tanh(atan(tanh(tanh(atan(sin(1/acos(1/asin(sqrt(x1 - 0.952751992827518/x1)))))/sqrt(1 - atan(sin(1/acos(1/asin(sqrt(x1 - 0.952751992827518/x1)))))**2))) + 28.1726627827596))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function add at 0x000001E8B58C6840>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   25.115775354781704,
#   -3],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sin((1/atan(log(log(x1) + 22.1157753547817)))**(1/4))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793,
#   3.141592653589793,
#   2.718281828459045,
#   -3],
#  []]

# %%
printGPModel(randomModel)
# Out:
# acos(5306.50749101821*exp(atan(0.318309886183791*tan(x0)/tanh(sin(x1)**2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', 'pop', 'pop', 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function log at 0x000001E8B7EBF2E0>], dtype=object),
#  [3,
#   2,
# ...

# %%
printGPModel(randomModel)
# Out:
# log(1/acos(3/tanh(atan(acos(atan(tan(sin(x0/atan(3.14159265358979*x0)) - 2))**2)**2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrt at 0x000001E8B7EBECA0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# cos(((-x0 + sqrt(x1))/x1)**(1/4))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sin at 0x000001E8B7EBEE80>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tanh at 0x000001E8B7EBF240>], dtype=object),
#  [2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   1,
#   10.65510337052785,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793,
# ...

# %%
printGPModel(randomModel)
# Out:
# tanh(tan(tan(acos(x1/tan(1)) + 3.5523739440927 - 10.6551033705279/x0)) - 9.81002035704111*I)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# exp(-3.911102790395*(0.997690585837565*x1 - tanh(tan(1)))*sqrt((0.255682362134749*cos(7.38905609893065*(0.367879441171442*tanh(cos(x1)) - 1)**2 - atan(asin(x1))) - 0.401624915267506 + I)**2 + 0.0653734703068047)/(cos(7.38905609893065*(0.367879441171442*tanh(cos(x1)) - 1)**2 - atan(asin(x1))) - 1.5707963267949 + 3.911102790395*I))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# -tan(x0 - 0.318309886183791*asin(-x0 + 3 + atan(cos(1/atan(0.0457019110445752/sqrt(15.6957954159673 + I*pi))))))/sqrt(1 - tan(x0 - 0.318309886183791*asin(-x0 + 3 + atan(cos(1/atan(0.0457019110445752/sqrt(15.6957954159673 + I*pi))))))**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function mult at 0x000001E8B7EBEAC0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# x0*log(x1)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function cos at 0x000001E8B7EBEF20>], dtype=object),
#  [2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# cos(2.71828182845905 - 1.21828290501728/x0)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.053030428699036146

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sub at 0x000001E8B7EBEA20>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# sqrt(log(0.318309886183791*x1**2*(atan(log(3.14159265358979 - x1)) - 3.11331819510162e-11) - 0.318309886183791*x1)/asin(1/tan(0.986109509444502*exp(-tan(x1 - 1/sin(x0))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   -3,
# ...

# %%
printGPModel(randomModel)
# Out:
# tanh(1/(x0**2 - atan(tan(3.14159265358979*log(x0) - cos(log(-3*cos(tanh(sin(x0)))))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sin at 0x000001E8B7EBEE80>,
#         <function add at 0x000001E8B58C6840>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function protectDiv at 0x000001E8B0D99E40>], dtype=object),
#  [3.141592653589793, 3.141592653589793, -3],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -sqrt(log(1.81152627246085*I))/3

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function add at 0x000001E8B58C6840>], dtype=object),
#  [27.12579077069292,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3,
#   25.595680764090442,
#   17.397932730970542,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# x0 + 445.311932137042*sin(log((27.1257907706929 - x0)/x0)/3)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop'], dtype=object),
#  [27.40570204468192,
#   22.828363566629598,
#   3.141592653589793,
#   3.141592653589793,
#   22.91547970937655,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   21.122883565876762,
#   2.718281828459045,
#   3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1.77267844071465*sqrt(0.902942783842507 + 1/(x0*x1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# acos(acos(atan(x1)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# asin(x0 + 3) - 0.0302764208947562

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function add at 0x000001E8B58C6840>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# asin(cos(cos(exp(tan(x0)))) - acos(pi/2 - 1.10663760967507e-8*I)**2) + x1/x0

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>], dtype=object),
#  [3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1.0/x1

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0014737152490746175

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arcsin at 0x000001E8B7EBF100>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop'], dtype=object),
#  [3.141592653589793, -2, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(asin(asin(atan(2.71828182845905*exp(-asin(sin(2 - log(sqrt(cos((1.5707963267949 - 1.81152627246085*I)**2))))))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function add at 0x000001E8B58C6840>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function arcsin at 0x000001E8B7EBF100>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
# ...

# %%
printGPModel(randomModel)
# Out:
# 3.14159265358979*sqrt(cos(0.318309886183791*tanh(x1)**2)**2 + 1)*exp(x0 + exp(3)) - acos(-sin(exp(asin(x1)) - 9))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function add at 0x000001E8B58C6840>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# tanh(atan(log(atan(10.0921829201245 + 19.2016028322475/log(tanh(tanh(cos(log(x1)))))))))**2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         'pop', <function arctan at 0x000001E8B7EBF1A0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# acos(cos(tan(exp(x1)*asin(log(acos(-atan(atan(atan(sin(sin(0.862609879394536/(sin(sin(sin(1)))*acos(acos(tan(2)))))))))))**2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function protectDiv at 0x000001E8B0D99E40>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   -3,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [3.141592653589793,
#   16.661035582613934,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793,
#   2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 0.207879576350762 - 8.53973422267357*tanh(tanh(x0 + 16.6610355826139))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.024477036126698586

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function mult at 0x000001E8B7EBEAC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sqrd at 0x000001E8B7EBED40>], dtype=object),
#  [3.141592653589793, 1, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 6.07965315727681*exp(-0.276368293022759*I)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(1/cos(exp(x1)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function inv at 0x000001E8B7EBEDE0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   1,
# ...

# %%
printGPModel(randomModel)
# Out:
# exp(acos(acos(cos(sin(tan(0.367879441171442*exp(1/x1) - 0.367879441171442)))**(-2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -x1 + asin(sin(x1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.002273325156269859

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tan at 0x000001E8B7EBEFC0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop'], dtype=object),
#  [2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -0.435460294770010

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop'], dtype=object),
#  [2.718281828459045, 2.718281828459045, 14.158150113879362],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 0.277638780339550

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function arccos at 0x000001E8B7EBF060>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop', 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop'], dtype=object),
# ...

# %% [raw]
# printGPModel(randomModel)

# %%
printGPModel(randomModel)
# Out:
# atan(sin(sqrt(sin(sqrt(tanh(1/tan(tanh(atan(cos(sin(exp(acos(x1)))**2))))))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop'], dtype=object),
#  [2.718281828459045, 1],
#  []]

# %%
printGPModel(randomModel)
# Out:
# cos(2.58789162712009/tanh(1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function arctan at 0x000001E8B7EBF1A0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>,
# ...

# %%
printGPModel(randomModel)
# Out:
# cos(exp(cos(-x1*atan(x0) + x1 - tanh(atan(x1 - exp(atan(x1)**2))) + 38.5408790547369 + 1/cos(x0))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.13620740513199014

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function add at 0x000001E8B58C6840>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
# ...

# %%
printGPModel(randomModel)
# Out:
# nan

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop'], dtype=object),
#  [3.141592653589793, 3.141592653589793, 2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 2.66175159634611

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# sqrt(acos(tanh(sqrt(1.0 - cos(1.37480222743936*exp(-cos(sin(tan(1.56232905080621e-9*exp(-4.81047738096535*exp(-1.65745445415308*I)))))))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
# ...

# %%
printGPModel(randomModel)
# Out:
# exp(2188.38072508853/tanh(x1 - 12.6528242690066*(-0.281129397501149*cos(asin(atan(log(x0)) - 1/atan(exp(atan(atan(acos(tan(x0))))))) + 0.811621814796338*I) + I)**2)**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop', 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop'],
#        dtype=object),
#  [-2,
#   3.141592653589793,
# ...

# %%
printGPModel(randomModel)
# Out:
# tan(tanh(0.99627207622075*acos(tanh(x0))) - 5.5386700175207)**4

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.16649350888018635

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function add at 0x000001E8B58C6840>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# x0**2 + cos(x0)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function log at 0x000001E8B7EBF2E0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function protectDiv at 0x000001E8B0D99E40>], dtype=object),
#  [24.57340938022087,
#   27.516784111965833,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -27.2044466190961/tan(x0)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009855867379780676

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arccos at 0x000001E8B7EBF060>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop', 'pop'],
#        dtype=object),
#  [-1, <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# cos(x0)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function arcsin at 0x000001E8B7EBF100>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function add at 0x000001E8B58C6840>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# sqrt(exp(x0*(0.367879441171442*x0*(1.09308894430707 - 1.60448739277804*I) + 2.71828182845905)/acos(log(log(1/(pi/2 - 0.787114738447319*I))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sin at 0x000001E8B7EBEE80>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function add at 0x000001E8B58C6840>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# 1.50799550754975 - asin(asin(tanh(3.14159265358979/log(2.71828182845905 - 1.31672297652942*(0.8714707057734*x0 + 1)**2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tan at 0x000001E8B7EBEFC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function log at 0x000001E8B7EBF2E0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# acos(cos(log(tan(log(exp(-sin(2.71828182845905*exp(tanh(x1)**2/sin(9)) - 2.29593121027903 + acos(atan(2)))))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793,
#   2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1/(x1 + 2.69104311951999)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function log at 0x000001E8B7EBF2E0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   21.92822402281509,
#   1,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   19.791455776286604,
#   22.95262127328992,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(x1 + 0.0435680085552453*(x1 - 21.9282240228151)*acos(pi/2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrd at 0x000001E8B7EBED40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# -sqrt(-asin(x1*tan(0.995838366393924*sqrt(x1)*(1.00208252335482 + 0.00310508688071521*I)) + tanh(x1) + acos(x0) - 2))*sin(x0 - 0.479641628586553)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function mult at 0x000001E8B7EBEAC0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop'], dtype=object),
#  [1, <function StackGP.variableSelect.<locals>.<lambda>(variables)>, 3],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1/atan(asin(tanh(acos(x0) - tanh(atan(log(3))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# asin(1/atan(sqrt(acos(log(tan(tanh(sqrt(acos(x0 + 2.71828182845905*sqrt(0.135335283236613 - (0.367879441171442*x0 + 1)**2)*sin(1.81982910656353*x0)/(x0 + 2.71828182845905)))))**(1/4))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function add at 0x000001E8B58C6840>,
# ...

# %%
printGPModel(randomModel)
# Out:
# asin(2.71828182845905 + sin(0.367879441171442/sin(atan(23.1406926327793*exp(-1.80143501691249*I))/tanh(14.8915419675532*atan(pi/2)))))**2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# nan

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
# ...

# %%
printGPModel(randomModel)
# Out:
# -x1 + atan(tan(asin(tanh(0.0703869255530436*tanh(atan(tan(x1))))) + 0.423310825130748)) + 3.15096229936441/asin(sin(7.38905609893065*(0.367879441171442*asin(x1) - 1)**2)**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function log at 0x000001E8B7EBF2E0>], dtype=object),
#  [3.141592653589793, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# nan

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sqrd at 0x000001E8B7EBED40>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function exp at 0x000001E8B7EBEB60>], dtype=object),
#  [12.160865210783228,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   -2],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(0.236030131675273*exp(2)/x1)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop'],
#        dtype=object),
#  [2.718281828459045, 19.00999862137344, 1],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 51.6745338115109*exp(-1)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop'], dtype=object),
# ...

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop'], dtype=object),
# ...

# %%
printGPModel(randomModel)
# Out:
# nan

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# cos(0.182738351164852 + log(atan(log(sqrt(exp(cos(cos(2.49721755683577 - I*pi))))*asin(acos(2))/sqrt(1 + exp(cos(cos(2.49721755683577 - I*pi)))))))**4)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [13.790907398687223,
# ...

# %%
printGPModel(randomModel)
# Out:
# 1.49841146927714 - asin(x0**2*acos(log(acos(sin(0.564189583547756*log(atan(cos(tanh(x0)))) + 3.14159265358979)**2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(exp(sin((log(exp(atan(tan(x1**2))**2)) - 0.410781290502909)*atan(x1))**2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0010797155614371034

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function sin at 0x000001E8B7EBEE80>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function add at 0x000001E8B58C6840>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function inv at 0x000001E8B7EBEDE0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
# ...

# %%
printGPModel(randomModel)
# Out:
# 1/atan(sqrt(exp(-asin(x0 + tan(sin(log(x0)))**(-2)))/(x0 + x1)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sqrt at 0x000001E8B7EBECA0>], dtype=object),
#  [3.141592653589793, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(cos(exp(1.22386422275939*I)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sin at 0x000001E8B7EBEE80>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   -2,
#   2.718281828459045,
#   3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 3.14173805855224*exp(sin(x1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0015314443928024668

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>, 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>], dtype=object),
#  [-2,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793,
#   2.718281828459045,
#   3.141592653589793,
#   0],
#  []]

# %%
printGPModel(randomModel)
# Out:
# nan

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function tanh at 0x000001E8B7EBF240>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
# ...

# %%
printGPModel(randomModel)
# Out:
# acos(log(x0*(-1.00005599039455 - 9.0395800918287e-5*I)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function add at 0x000001E8B58C6840>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function inv at 0x000001E8B7EBEDE0>], dtype=object),
#  [1, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -2.11210322652301

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function tanh at 0x000001E8B7EBF240>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>, 0, 3],
#  []]

# %%
printGPModel(randomModel)
# Out:
# tanh(atan(asin(asin(tanh(x1)))**2/sqrt(1 - asin(asin(tanh(x1)))**4)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function add at 0x000001E8B58C6840>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function inv at 0x000001E8B7EBEDE0>], dtype=object),
#  [17.55751539392799,
#   -1,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   18.98611689409121,
#   27.81116859378503,
#   3,
# ...

# %%
printGPModel(randomModel)
# Out:
# acos(1/sqrt(-tan(3) + 18.9861168940912 - cos(27.811168593785 + 0.318309886183791*acos(3))))/(x0 + 17.557515393928*E)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop', 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function add at 0x000001E8B58C6840>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# sqrt(1 - asin(306.616224468065*(0.0571087210414448*log(x1) + 0.0571087210414448*acos(acos(0.112120002373016*x1*exp(atan(2)))) + 1)**2)**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         'pop', <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function exp at 0x000001E8B7EBEB60>], dtype=object),
#  [2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# exp(tanh(1.64872127070013*sqrt(0.367879441171442*acos(exp(x1)) + 1)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>], dtype=object),
#  [12.328092949861052,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# tanh(1.46613888250914*atan(x1)**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 4.670637884713705e-05

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(log(x1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arcsin at 0x000001E8B7EBF100>,
# ...

# %%
printGPModel(randomModel)
# Out:
# 7.38905609893065*asin(cos(-0.9913289158006*sqrt(x0**2 + 1) + atan(cos(2)) + 1)**4) + 187.479840520077

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045,
#   2.718281828459045,
#   24.73543120866439,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
# ...

# %%
printGPModel(randomModel)
# Out:
# 2.71828182845905*sqrt(exp(tan(cos(tan(24.7354312086644/x1))))*acos(exp(x1)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# sqrt(1 - x1**2) + tanh(acos((-0.314956396990617 + 1/(-0.0338352805801012 + 1/x0))/x0)) - 24.1592559128896

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function arccos at 0x000001E8B7EBF060>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arcsin at 0x000001E8B7EBF100>,
# ...

# %%
printGPModel(randomModel)
# Out:
# x1 + asin(acos(atan(atan(pi/2)/(3.14159265358979 - acos(log(28.827964627213*sin(x0)) - asin(atan(cos(x1))))))**2)**2)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sqrt at 0x000001E8B7EBECA0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arcsin at 0x000001E8B7EBF100>], dtype=object),
#  [15.621040601396249,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   24.737476323706176],
#  []]

# %%
printGPModel(randomModel)
# Out:
# asin(0.290210588393007*(1.5707963267949 + 0.989127168324762*I)*(3.95234621476867 - x0))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function add at 0x000001E8B58C6840>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>,
# ...

# %%
printGPModel(randomModel)
# Out:
# acos(0.551409782313362/log((tan(sin(sqrt(x0))) - 1.21828290501728)*asin(atan(1/(log(sin(2)) + 0.96532404258905)))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop'], dtype=object),
#  [2.718281828459045, 13.396144117728904, 2],
#  []]

# %%
printGPModel(randomModel)
# Out:
# tan(0.00290449602611055 - acos(tan(log(2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function add at 0x000001E8B58C6840>,
# ...

# %%
printGPModel(randomModel)
# Out:
# 1/((178.520132948621*x0**2 - 1)*(-2.08527964547896e-6*exp(x0) + exp(atan(x0))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arcsin at 0x000001E8B7EBF100>,
#         <function add at 0x000001E8B58C6840>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrt at 0x000001E8B7EBECA0>], dtype=object),
#  [15.551786908986958,
#   2.718281828459045,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(tan(exp((-1.00000000002513 + 3.26335756412423e-11*I)/x0)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function arcsin at 0x000001E8B7EBF100>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop', 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>], dtype=object),
#  [-1,
#   3.141592653589793,
#   2.718281828459045,
# ...

# %%
printGPModel(randomModel)
# Out:
# (-2.5707963267949 + 1.81152627246085*I)/log(2.71828182845905/acos(acos(0.65575521383956*exp(0.875097240574115*I*pi))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', 'pop', <function arcsin at 0x000001E8B7EBF100>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop', 'pop',
#         'pop', 'pop', 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop'], dtype=object),
#  [2.718281828459045,
#   12.317432316555031,
#   3.141592653589793,
#   11.105731779529734,
#   3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1.74184729270698 + 3.3881317890172e-20*I

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop'], dtype=object),
#  [24.009658553900703,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sin((1.5707963267949 - 3.87116940866016*I)*asin(0.9042647725749*x1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop'], dtype=object),
#  [-2, -1, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# tanh(log(atan(sin((1.8150840983588 + I*pi)**2)**2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop', 'pop'],
#        dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# acos(log(log(x0)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function exp at 0x000001E8B7EBEB60>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop'], dtype=object),
#  [2,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045,
#   16.830857118508728],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 158870829.519917*tanh(sin(sin(x0*exp(2))))**2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.001117173162171815

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function arctan at 0x000001E8B7EBF1A0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop'], dtype=object),
#  [13.246136701000541],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1.25828236908491

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function exp at 0x000001E8B7EBEB60>,
#         <function sin at 0x000001E8B7EBEE80>], dtype=object),
#  [3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -0.912577598669278

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %% [markdown]
# # Range [-1,1]

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function inv at 0x000001E8B7EBEDE0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arccos at 0x000001E8B7EBF060>], dtype=object),
# ...

# %%
printGPModel(randomModel)
# Out:
# acos(exp(22.2299100685923*(x1 + 31.069285997292)/log(asin(x0)/acos(sin(sqrt(acos(sin(x0)**2)) + 11.2624315576293)))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function log at 0x000001E8B7EBF2E0>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   21.047604967389244,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 1/atan(exp(exp(acos(asin(tanh(4.58776688241559*x1/cos(x0)))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function exp at 0x000001E8B7EBEB60>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function protectDiv at 0x000001E8B0D99E40>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arctan at 0x000001E8B7EBF1A0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# sin(log(sin(sqrt(tan(1.77245385090552*sqrt(0.318309886183791*cos(tan(exp(x0))) - 1) - atan(asin(atan(2.71828182845905*log(tan(3.14159265358979*sqrt(0.101321183642338 - (0.318309886183791*x1 - 1/x0)**2)/(x1 - 3.14159265358979/x0))/sqrt(tan(3.14159265358979*sqrt(0.101321183642338 - (0.318309886183791*x1 - 1/x0)**2)/(x1 - 3.14159265358979/x0))**2 + 1))))))))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function sqrt at 0x000001E8B7EBECA0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>], dtype=object),
#  [1, 12.814762051876809],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 0.774727404503137

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop', 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop', 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# nan

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop', 'pop', 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
# ...

# %%
printGPModel(randomModel)
# Out:
# -sin(x0)*tan(sin(x1) - 0.312961796207787)/asin(sqrt(3.14159265358979 - 1.30753004155465*I))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function inv at 0x000001E8B7EBEDE0>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop'], dtype=object),
#  [3.141592653589793, 2.718281828459045, 3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -2.39997194227525 - cos(4.81047738096535*exp(-1.81152627246085*I))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function tan at 0x000001E8B7EBEFC0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function sqrt at 0x000001E8B7EBECA0>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop', 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sqrt at 0x000001E8B7EBECA0>,
# ...

# %%
printGPModel(randomModel)
# Out:
# nan

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tanh at 0x000001E8B7EBF240>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# -x1 + sin(tanh(x1))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.002445368687083621

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function cos at 0x000001E8B7EBEF20>], dtype=object),
#  [15.151371126927113,
# ...

# %%
printGPModel(randomModel)
# Out:
# cos(1/tanh(log(cos(3.14159265358979*exp(tanh(exp(1/asin(atan(x1))))))) - 0.348406328918336*I))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sub at 0x000001E8B7EBEA20>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function add at 0x000001E8B58C6840>,
#         <function exp at 0x000001E8B7EBEB60>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop', 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop'], dtype=object),
#  [0,
#   -2,
#   2.718281828459045,
#   -3,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(1/acos(log(229.651664083524*(exp(cos(4)) - 0.197964107535938/sqrt(log(x1)))**2)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sqrt at 0x000001E8B7EBECA0>, 'pop'], dtype=object),
#  [0],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 0

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %% [markdown]
# # Range [100,105]

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function arctan at 0x000001E8B7EBF1A0>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrd at 0x000001E8B7EBED40>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(atan(acos(1/asin(asin(1/sqrt(cos(x0)))))))**2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function add at 0x000001E8B58C6840>,
#         <function cos at 0x000001E8B7EBEF20>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop', 'pop',
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function sin at 0x000001E8B7EBEE80>, 'pop', 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
# ...

# %%
printGPModel(randomModel)
# Out:
# log(0.457734156102466/(-167.371893393666*(0.0772963052910444*sin(asin(x0) - 3.14159265358979) + 1)**2 - exp(1/sin(x1)) + tanh(sqrt(1/x0))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function inv at 0x000001E8B7EBEDE0>,
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop', 'pop',
#         'pop', <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop', 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sqrd at 0x000001E8B7EBED40>], dtype=object),
#  [20.11053629722155,
# ...

# %%
printGPModel(randomModel)
# Out:
# (tan(x1*cos(asin(x0 - 0.0158280157962654)**2)) + (-0.478073560301917 + I*pi)**4)**2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function tanh at 0x000001E8B7EBF240>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop', 'pop'],
#        dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3.141592653589793],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(tanh(sin(9.86960440108936*tanh(atan(acos(x0) - 1/x0)/x0))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function protectDiv at 0x000001E8B0D99E40>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop'], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# acos(0.367879441171442*x1)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function tanh at 0x000001E8B7EBF240>, 'pop',
#         <function sub at 0x000001E8B7EBEA20>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function add at 0x000001E8B58C6840>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop',
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function add at 0x000001E8B58C6840>,
#         <function protectDiv at 0x000001E8B0D99E40>,
# ...

# %%
printGPModel(randomModel)
# Out:
# -tanh(asin(exp(cos((sqrt(tanh(1)) + 0.99627207622075)/x0) + acos(-3)))) + log((tanh(x0) - 2.71828182845905)*cos(x1**2 + 3.14159265358979))/(x1 - 482.432204392897)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function add at 0x000001E8B58C6840>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function add at 0x000001E8B58C6840>,
#         <function arcsin at 0x000001E8B7EBF100>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function arctan at 0x000001E8B7EBF1A0>, 'pop',
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function log at 0x000001E8B7EBF2E0>,
#         <function sqrd at 0x000001E8B7EBED40>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function protectDiv at 0x000001E8B0D99E40>,
# ...

# %%
printGPModel(randomModel)
# Out:
# log(atan(0.318309886183791*acos(log(acos(x1*(atan(acos(asin(acos(sqrt(1/cos(cos(x0) - 2))) + 2))) + 2.71828182845905)))**2) - 0.014482122777706))**2

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function cos at 0x000001E8B7EBEF20>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function log at 0x000001E8B7EBF2E0>], dtype=object),
#  [22.93252656585166,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(0.555062445111405*sqrt(exp(-2*x0)))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009241987701188847

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function protectDiv at 0x000001E8B0D99E40>], dtype=object),
#  [<function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   19.455329317783196],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 0.0513997981563821*x1

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009357426143150684

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sub at 0x000001E8B7EBEA20>], dtype=object),
#  [3.141592653589793,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# 3.14159265358979 - x0

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# 0.0009409153487654881

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', 'pop', <function arcsin at 0x000001E8B7EBF100>,
#         <function add at 0x000001E8B58C6840>, 'pop',
#         <function tanh at 0x000001E8B7EBF240>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function tanh at 0x000001E8B7EBF240>, 'pop', 'pop'], dtype=object),
#  [14.545413269307499, 2],
#  []]

# %%
printGPModel(randomModel)
# Out:
# tanh(acos(tanh(14.5454132693075 + asin(2))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function tanh at 0x000001E8B7EBF240>,
#         <function sqrt at 0x000001E8B7EBECA0>,
#         <function arccos at 0x000001E8B7EBF060>,
#         <function sin at 0x000001E8B7EBEE80>,
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>, 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop',
#         <function protectDiv at 0x000001E8B0D99E40>,
#         <function cos at 0x000001E8B7EBEF20>,
#         <function arccos at 0x000001E8B7EBF060>, 'pop', 'pop', 'pop',
#         <function add at 0x000001E8B58C6840>,
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function add at 0x000001E8B58C6840>,
#         <function sub at 0x000001E8B7EBEA20>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function sqrt at 0x000001E8B7EBECA0>, 'pop',
# ...

# %%
printGPModel(randomModel)
# Out:
# exp(sqrt(acos(sqrt(1/(log(sqrt(1 - tanh(x0))) - tan(log(x0) + 0.668204772586941) + 1.22464679914735e-16)))))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array([<function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>,
#         <function exp at 0x000001E8B7EBEB60>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop', 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop', 'pop',
#         <function sub at 0x000001E8B7EBEA20>,
#         <function add at 0x000001E8B58C6840>, 'pop', 'pop',
#         <function log at 0x000001E8B7EBF2E0>, 'pop'], dtype=object),
#  [28.907262645984233,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   3,
#   24.147105220059405,
#   2.718281828459045],
#  []]

# %%
printGPModel(randomModel)
# Out:
# log(x1 + 8.35078506935863e+62)

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan

# %%
randomModel=generateRandomModel(2,allOps(),defaultConst(),40)

# %%
randomModel
# Out:
# [array(['pop', <function sqrt at 0x000001E8B7EBECA0>, 'pop',
#         <function sqrd at 0x000001E8B7EBED40>, 'pop', 'pop',
#         <function mult at 0x000001E8B7EBEAC0>, 'pop',
#         <function sin at 0x000001E8B7EBEE80>,
#         <function arcsin at 0x000001E8B7EBF100>, 'pop', 'pop', 'pop',
#         'pop', 'pop', <function add at 0x000001E8B58C6840>,
#         <function sqrd at 0x000001E8B7EBED40>, 'pop',
#         <function inv at 0x000001E8B7EBEDE0>, 'pop',
#         <function tan at 0x000001E8B7EBEFC0>,
#         <function inv at 0x000001E8B7EBEDE0>, 'pop', 'pop', 'pop',
#         <function exp at 0x000001E8B7EBEB60>,
#         <function protectDiv at 0x000001E8B0D99E40>, 'pop'], dtype=object),
#  [-3,
#   29.8349696973355,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>,
#   <function StackGP.variableSelect.<locals>.<lambda>(variables)>],
#  []]

# %%
printGPModel(randomModel)
# Out:
# sqrt(3)*I*exp(-1/tan(1.26211112733834e-6/(0.00112343719332161*asin(sin(x1**2)) + 1)**2))

# %%
totalSharpness(randomModel,inputData,response,numPerturbations=4000,percentPerturbation=0.2)
# Out:
# nan
